# %% [markdown]
# # IMPORT LIBRARY

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
df = pd.read_csv('housing.csv')

# %% [markdown]
# # OBTAINING INFORMATİON ABOUT DATA CONTENT

# %%
df.head()
# Out:
#    longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0    -122.23     37.88                41.0        880.0           129.0
# 1    -122.22     37.86                21.0       7099.0          1106.0
# 2    -122.24     37.85                52.0       1467.0           190.0
# 3    -122.25     37.85                52.0       1274.0           235.0
# 4    -122.25     37.85                52.0       1627.0           280.0
#
#    population  households  median_income  median_house_value ocean_proximity
# 0       322.0       126.0         8.3252            452600.0        NEAR BAY
# 1      2401.0      1138.0         8.3014            358500.0        NEAR BAY
# 2       496.0       177.0         7.2574            352100.0        NEAR BAY
# 3       558.0       219.0         5.6431            341300.0        NEAR BAY
# 4       565.0       259.0         3.8462            342200.0        NEAR BAY

# %%
df.describe()
# Out:
#           longitude      latitude  housing_median_age   total_rooms  \
# count  20640.000000  20640.000000        20640.000000  20640.000000
# mean    -119.569704     35.631861           28.639486   2635.763081
# std        2.003532      2.135952           12.585558   2181.615252
# min     -124.350000     32.540000            1.000000      2.000000
# 25%     -121.800000     33.930000           18.000000   1447.750000
# 50%     -118.490000     34.260000           29.000000   2127.000000
# 75%     -118.010000     37.710000           37.000000   3148.000000
# max     -114.310000     41.950000           52.000000  39320.000000
#
#        total_bedrooms    population    households  median_income  \
# count    20433.000000  20640.000000  20640.000000   20640.000000
# mean       537.870553   1425.476744    499.539680       3.870671
# std        421.385070   1132.462122    382.329753       1.899822
# min          1.000000      3.000000      1.000000       0.499900
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20640 entries, 0 to 20639
# Data columns (total 10 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   longitude           20640 non-null  float64
#  1   latitude            20640 non-null  float64
#  2   housing_median_age  20640 non-null  float64
#  3   total_rooms         20640 non-null  float64
#  4   total_bedrooms      20433 non-null  float64
#  5   population          20640 non-null  float64
#  6   households          20640 non-null  float64
#  7   median_income       20640 non-null  float64
#  8   median_house_value  20640 non-null  float64
#  9   ocean_proximity     20640 non-null  object
# dtypes: float64(9), object(1)
# memory usage: 1.6+ MB

# %%
len(df)
# Out:
# 20640

# %%
df.isna().sum()
# Out:
# longitude               0
# latitude                0
# housing_median_age      0
# total_rooms             0
# total_bedrooms        207
# population              0
# households              0
# median_income           0
# median_house_value      0
# ocean_proximity         0
# dtype: int64

# %% [markdown]
# # DATA CLEANSİNG AND PROCESSİNG

# %%
# total_bedrooms verisinin medyanını aldık ve null total_bedrooms verisine atadık.
# We took the median of total_bedrooms and assigned it to the null total_bedrooms data.

df["total_bedrooms"] = df["total_bedrooms"].fillna(df["total_bedrooms"].median())

# %%
df.isna().sum()
# Out:
# longitude             0
# latitude              0
# housing_median_age    0
# total_rooms           0
# total_bedrooms        0
# population            0
# households            0
# median_income         0
# median_house_value    0
# ocean_proximity       0
# dtype: int64

# %%
sns.scatterplot(x='total_bedrooms', y='households', data=df)
plt.show()

# %%
plt.figure(figsize=(10, 6))
sns.heatmap(df.select_dtypes(include=[np.number]).corr(), annot=True, cmap='coolwarm')
plt.title('Correlation Heatmap')
plt.show()

# %% [raw]
# Birbiriyle yüksek korelasyon gösteren sütunları modelden çıkarmak veya bunlardan yeni, daha anlamlı özellikler türetmek çok mantıklıdır. Bu süreç makine öğrenimi dünyasında özellik mühendisliği olarak adlandırılır ve model performansını iyileştirmede kritik bir adımdır.
#
# Bir model birbiriyle güçlü bir şekilde ilişkili iki değişken gördüğünde (örneğin, toplam_odalar ve haneler), hangisinin hedef değişkeni (medyan_ev_değeri) öncelikli olarak etkilediğini anlamakta zorlanır. Bu da modelin katsayılarının istikrarsız olmasına ve yorumlanmasının zorlaşmasına neden olur. Kısacası, modelin kafası karışır ve bu da performansını düşürebilir. Bu nedenle, yüksek korelasyona sahip sütunların ortalamasını alacağız.
#
# It makes a lot of sense to remove columns that are highly correlated with each other from the model or derive new, more meaningful features from them. This process is called feature engineering in the world of machine learning and is a critical step in improving model performance.
#
# When a model sees two variables that are strongly related to each other (e.g., total_bedrooms and households), it struggles to understand which one primarily affects the target variable (median_house_value). This causes the model's coefficients to be unstable and difficult to interpret. In short, the model becomes confused, which can reduce its performance. For this reason, we will take the average of columns with high correlation.

# %%
df["rooms_per_household"] = df["total_rooms"] / df["households"]
df["bedrooms_per_room"] = df["total_bedrooms"] / df["total_rooms"]
df["population_per_household"] = df["population"] / df["households"]

# %%
df.head()
# Out:
#    longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0    -122.23     37.88                41.0        880.0           129.0
# 1    -122.22     37.86                21.0       7099.0          1106.0
# 2    -122.24     37.85                52.0       1467.0           190.0
# 3    -122.25     37.85                52.0       1274.0           235.0
# 4    -122.25     37.85                52.0       1627.0           280.0
#
#    population  households  median_income  median_house_value ocean_proximity  \
# 0       322.0       126.0         8.3252            452600.0        NEAR BAY
# 1      2401.0      1138.0         8.3014            358500.0        NEAR BAY
# 2       496.0       177.0         7.2574            352100.0        NEAR BAY
# 3       558.0       219.0         5.6431            341300.0        NEAR BAY
# 4       565.0       259.0         3.8462            342200.0        NEAR BAY
#
#    rooms_per_household  bedrooms_per_room  population_per_household
# ...

# %%
df = df.drop(["total_rooms","total_bedrooms","population","households"], axis=1)

# %%
plt.figure(figsize=(10, 6))
sns.heatmap(df.select_dtypes(include=[np.number]).corr(), annot=True, cmap='coolwarm')
plt.title('Correlation Heatmap')
plt.show()

# %% [markdown]
# # TRAIN TEST SPLIT

# %%
X = df.drop(["median_house_value","ocean_proximity"],axis=1)
y = df["median_house_value"]

# %%
from sklearn.model_selection import train_test_split

# %%
X_train, X_test, y_train, y_test = train_test_split(X,y, test_size=0.2, random_state=9)

# %% [markdown]
# # REGRESSION MODEL

# %% [raw]
# # LINEAR REGRESSION

# %%
from sklearn.linear_model import LinearRegression

# %%
regression = LinearRegression()

# %%
regression.fit(X_train,y_train)
# Out:
# LinearRegression()

# %%
test_pred = regression.predict(X_test)
test_pred[:10]
# Out:
# array([178249.27764842, 285443.29105081, 163851.04634096, 145351.13538855,
#        194251.94110831, 287122.11820458, 182691.81099331,  62066.8901996 ,
#        222682.00787165, 212958.21525161])

# %%
from sklearn.metrics import r2_score, mean_absolute_error, mean_squared_error

print("Theta :     ", round(regression.coef_[0],2))
print("Intercept : ", round(regression.intercept_,2))
print("R^2 :       ", round(r2_score(y_test,test_pred),2))
print("MAE :       ", round(mean_absolute_error(y_test,test_pred),2))
print("RMSE :      ", round(np.sqrt(mean_squared_error(y_test,test_pred)),2))
# Out:
# Theta :      -44480.86
# Intercept :  -3818068.83
# R^2 :        0.6
# MAE :        53152.41
# RMSE :       73453.84

# %%
mae = mean_absolute_error(y_test, test_pred)
mse = mean_squared_error(y_test, test_pred)
score = r2_score(y_test, test_pred)
print("Mean Absolute Error: ", mae)
print("Mean Squared Error: ", mse)
print("R2 Score: ", score)
plt.scatter(y_test, test_pred)
plt.show()
# Out:
# Mean Absolute Error:  53152.40827133106
# Mean Squared Error:  5395466959.68974
# R2 Score:  0.5983368931852748

# %% [raw]
# # LASSO

# %%
from sklearn.linear_model import Lasso
lasso = Lasso()
lasso.fit(X_train,y_train)
lasso_test_pred = lasso.predict(X_test)
mae = mean_absolute_error(y_test, lasso_test_pred)
mse = mean_squared_error(y_test, lasso_test_pred)
score = r2_score(y_test, lasso_test_pred)
print("Mean Absolute Error: ", mae)
print("Mean Squared Error: ", mse)
print("R2 Score: ", score)
plt.scatter(y_test, lasso_test_pred)
plt.show()
# Out:
# Mean Absolute Error:  53153.25844840402
# Mean Squared Error:  5395462397.608365
# R2 Score:  0.5983372328073673

# %% [raw]
# # RIDGE

# %%
from sklearn.linear_model import Ridge
ridge = Ridge()
ridge.fit(X_train,y_train)
ridge_test_pred = ridge.predict(X_test)
mae = mean_absolute_error(y_test, ridge_test_pred)
mse = mean_squared_error(y_test, ridge_test_pred)
score = r2_score(y_test, ridge_test_pred)
print("Mean Absolute Error: ", mae)
print("Mean Squared Error: ", mse)
print("R2 Score: ", score)
plt.scatter(y_test, ridge_test_pred)
plt.show()
# Out:
# Mean Absolute Error:  53164.540955231045
# Mean Squared Error:  5395591348.172288
# R2 Score:  0.5983276331407366

# %% [raw]
# # ELASTICNET

# %%
from sklearn.linear_model import ElasticNet
elastic = ElasticNet()
elastic.fit(X_train,y_train)
elastic_test_pred = elastic.predict(X_test)
mae = mean_absolute_error(y_test, elastic_test_pred)
mse = mean_squared_error(y_test, elastic_test_pred)
score = r2_score(y_test, elastic_test_pred)
print("Mean Absolute Error: ", mae)
print("Mean Squared Error: ", mse)
print("R2 Score: ", score)
plt.scatter(y_test,elastic_test_pred)
plt.show()
# Out:
# Mean Absolute Error:  57625.836538095195
# Mean Squared Error:  6051639054.199458
# R2 Score:  0.5494884572565606

# %% [raw]
# # LASSO CROSS VALIDATION

# %%
from sklearn.linear_model import LassoCV
lassocv = LassoCV(cv=5)
lassocv.fit(X_train,y_train)
lassocv_test_pred = lassocv.predict(X_test)
mae = mean_absolute_error(y_test, lassocv_test_pred)
mse = mean_squared_error(y_test, lassocv_test_pred)
score = r2_score(y_test, lassocv_test_pred)
print("Mean Absolute Error: ", mae)
print("Mean Squared Error: ", mse)
print("R2 Score: ", score)
plt.scatter(y_test, lassocv_test_pred)
plt.show()
# Out:
# Mean Absolute Error:  53310.03607842729
# Mean Squared Error:  5400951417.720488
# R2 Score:  0.5979286051782713

# %% [raw]
# # RIDGE CROSS VALIDATION

# %%
from sklearn.linear_model import RidgeCV
ridgecv = RidgeCV(cv=5)
ridgecv.fit(X_train,y_train)
ridgecv_test__pred = ridgecv.predict(X_test)
mae = mean_absolute_error(y_test, ridgecv_test__pred)
mse = mean_squared_error(y_test, ridgecv_test__pred)
score = r2_score(y_test, ridgecv_test__pred)
print("Mean Absolute Error: ", mae)
print("Mean Squared Error: ", mse)
print("R2 Score: ", score)
plt.scatter(y_test, ridgecv_test__pred)
plt.show()
# Out:
# Mean Absolute Error:  53267.774366226375
# Mean Squared Error:  5399226875.319792
# R2 Score:  0.5980569879602756

# %% [raw]
# # ELASTICNET CROSS VALIDATION

# %%
from sklearn.linear_model import ElasticNetCV
elasticcv = ElasticNetCV(cv=5)
elasticcv.fit(X_train,y_train)
elasticcv_test_pred = elasticcv.predict(X_test)
mae = mean_absolute_error(y_test, elasticcv_test_pred)
mse = mean_squared_error(y_test, elasticcv_test_pred)
score = r2_score(y_test, elasticcv_test_pred)
print("Mean Absolute Error: ", mae)
print("Mean Squared Error: ", mse)
print("R2 Score: ", score)
plt.scatter(y_test, elasticcv_test_pred)
plt.show()
# Out:
# Mean Absolute Error:  89703.79676983236
# Mean Squared Error:  12980707527.333742
# R2 Score:  0.03365707675800922
